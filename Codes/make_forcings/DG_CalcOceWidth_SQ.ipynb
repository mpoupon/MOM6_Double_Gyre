# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset('/scratch/cimes/GEOCLIM/LRGROUP/mpoupon/simulations/DG-plane/DG-sq-rescaling/ice_ocean_SIS2/OM4_DG_COBALT/INPUT/code/model_ocean_widths.nc')

# %%
dx = 85000
nx = 40

# %%
ds['mwidth'] = xr.DataArray(data = np.full(len(ds.lat), nx*dx, dtype = float), dims=["lat"], coords=dict(lat = ds.lat))

# %%
plt.plot(ds.lat, ds.owidth)
plt.plot(ds.lat, ds.mwidth)

# %%
ds.to_netcdf('./model_ocean_widths_sq.nc')
